# %% [markdown]
# ## standard imports

# %%
import pandas as pd
import numpy as np
import sqlite3 as sql
import requests
import json
import re
import pprint
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import time
from bs4 import BeautifulSoup
#from termcolor import colored

# %% [markdown]
# ## setting up sqlite

# %%
database = "pitchfork.sqlite"
conn = sql.connect(database)
c = conn.cursor()

# %%
band_query = """
SELECT 
    r.artist,
    y.year,
    COUNT(*) counter
FROM reviews r
INNER JOIN years y ON y.reviewid == r.reviewid
GROUP BY r.artist
"""
df_bands = pd.read_sql_query(band_query, conn)

# %%
bands = df_bands.artist
bands[150:160]
# Out:
# 150               africa hitech
# 151               africaine 808
# 152         african head charge
# 153           african virtuoses
# 154    africans with mainframes
# 155            afrika bambaataa
# 156                   afrirampo
# 157                  afterhours
# 158                         afx
# 159                 against me!
# Name: artist, dtype: object

# %% [markdown]
# ## We're trying three different approaches
# 1. Using genders from Wikidata
# 2. Using Categories from Wikipedia with the wiki API
# 3. Counting Pronouns

# %% [markdown]
# ## 1. Approach: Using Wikidata

# %%
def find_gender_data(url, http):
    """
    given the unique wikidata URL of a profile,
    this function returns the gender if it is given
    """
    gender = "unknown"
    response = http.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    spoon = soup.find('div', id= "P21")
    if spoon != None:
        gender = spoon.find("div", class_="wikibase-snakview-value wikibase-snakview-variation-valuesnak").get_text()     
    return gender

def find_page_id_data(base_url, artist, http, pattern=r'(?<=#58;)(.*)(?=&#124)'):
    """
    given an artist name,
    this function return the unique wikidata URL to the artist.
    To avoid dissambiguation we add the suffixes when necessary...
    """
    variations = ['_(band)', '_(musician)', '_(singer)', '_(rapper)', '']
    for variation in variations:
        url = base_url + artist + variation
        
        response = http.get(url)
        soup = BeautifulSoup(response.text, "html.parser")
        spoon = soup.find_all('th', {'id': re.compile(r'&#58')})
        
        if len(spoon) > 0:
            spoon = spoon[0].get("id")
            m = re.search(pattern, spoon)
            link = "https:" + m.group(0)
            #print(colored(f'found with suffix {variation}', 'green'))
            return link 
            
    #print(colored(f'nothing found for {band}', 'red'))
    return  None


def get_wikidata(artist_list, verbose=True):
    """
    the wikidata approach to finding the data.
    We use the unique identifier wikidata pages and scrape them with bs4 to get
    info about the artists gender
    the function takes a list of artists and returns a dictionary with the 
    artists and their respective genders"""
    
    time_before = time.time()
    
    #### setup    
    artist_list = artist_list.str.title().str.strip().str.replace(" ", "_").str.replace("&", "%26")
    base_url = "https://en.wikipedia.org/wiki/"
    pattern = r'(?<=#58;)(.*)(?=&#124)'
    band_dict = {}
    time_before = time.time()
        
    #### retry strategy
    retry_strategy = Retry(
        total=3,
        status_forcelist=[429, 500, 502, 503, 504],
        method_whitelist=["HEAD", "GET", "OPTIONS"]
    )
    adapter = HTTPAdapter(max_retries=retry_strategy)
    http = requests.Session()
    http.mount("https://", adapter)
    http.mount("http://", adapter)

    
    for counter, artist in enumerate(artist_list): 
        
        #### find the wikidata page link
        link = find_page_id_data(base_url, artist, http)
        gender = "unknown"

        #### tells us how we're doing with the algorithm
        if verbose:
            print (f"working on band number {counter} of {len(artist_list)}", end="\r")
        
        #### results
        if link != None:
            gender = find_gender_data(link, http) 
        band_dict[artist] = gender
        
        #print(artist, gender) 
        
        
    #### timer for final print
    elapsed_time = time.time() - time_before
    print(f"this approach took {elapsed_time} seconds for a total of {len(artist_list)} bands")
    
    return band_dict

# %%
band_dict_data = get_wikidata(bands[2000:2500], verbose=True)
# Out:
# this approach took 1322.7043149471283 seconds for a total of 500 bands

# %%
df_data = pd.DataFrame(pd.Series(band_dict_data).values, pd.Series(band_dict_data).index)
df_data.rename(columns={0: "gender_data"}, inplace=True)
df_data.index.name = "artist"

# %% [markdown]
# ## 2. Approach: Use Categories via Wiki API

# %% [markdown]
# ### Some notes on the API
# the &redirects links directly to the final redirect. We then use the page_id of the final redirect to do our second query. (like in the last line in the next cell) This is important to get the right results...

# %%
# a standard API request
r = requests.get("https://en.wikipedia.org/w/api.php?action=query&format=json&prop=categories&redirects&titles=Ben_Harper")
r.json()

## A band without redirect.
r = requests.get("https://en.wikipedia.org/w/api.php?action=query&format=json&titles=Acid_Mothers_Temple_%26_The_Cosmic_Inferno")
r.json()

## A band with redirect. Note how it gives us a new pageid. The one of the final redirect...
r = requests.get("https://en.wikipedia.org/w/api.php?action=query&format=json&titles=Acid_Mothers_Temple_%26_The_Cosmic_Inferno&redirects")
r.json()

## A band with redirect that is already the final landing page. The query yields essentially the same results
r = requests.get("https://en.wikipedia.org/w/api.php?action=query&format=json&titles=Acid_Mothers_Temple&redirects")
r.json()

## A band with redirect and direct query for categories. The golden ticket...
r = requests.get("https://en.wikipedia.org/w/api.php?action=query&format=json&prop=categories&redirects&titles=Acid_Mothers_Temple_%26_The_Cosmic_Inferno")
_=r.json()

# %%
pp = pprint.PrettyPrinter()

def scrape_categories(band_list, redirect=True, verbose=True):
    """
    given a list of bands, this function returns all the categories the bands belong to on Wikipedia.
    The function does some preprocessing of the band names such as replacing spaces with "_" and 
    making the first letter of a word a capital and a few more operations...
    
    the function return a dict with the categories and a list of bands that have not been found
    
    redirect is a very important hypervariable. 
    It makes sure we look at the final redirect of the url we want to query. 
    We can turn it off, potentially speeding up the algorithm but that would yield inferior results...
    
    verbose just tells us where we're at in our process...
    """
    ### string preprocessing
    band_list = band_list.str.title().str.strip().str.replace(" ", "_").str.replace("&", "%26")
    
    #### setup
    not_found = []
    band_dict = {}
    time_before = time.time()
    base_url = 'https://en.wikipedia.org/w/api.php?action=query&format=json&prop=categories'
    
    if redirect:
        base_url += "&redirects"
        
    #### retry strategy
    retry_strategy = Retry(
        total=3,
        status_forcelist=[429, 500, 502, 503, 504],
        method_whitelist=["HEAD", "GET", "OPTIONS"]
    )
    adapter = HTTPAdapter(max_retries=retry_strategy)
    http = requests.Session()
    http.mount("https://", adapter)
    http.mount("http://", adapter)
    
    for counter,band in enumerate(band_list):
        
        ##### speakerbox
        if verbose:
            print (f"working on band number {counter} of {len(band_list)}", end="\r")
            
        #### setup. We set up a helperfunction to return the page_id and the parsed query from an artist         
        page_id, url, parsed, suffix = find_page_id_cat(base_url, band, http)

        #### page_id -1 indicates a non-existant page. all other cases will be stripped in else
        if page_id == "-1":
            not_found.append(band)  
            
        else:
            category_path = parsed.get("query").get("pages").get(page_id).get("categories")
            category_list = []
            for categories in category_path:
                category_list.append(categories.get("title").replace("Category:", ""))
  
            continuation = parsed.get("continue")           
            while continuation != None: #### The api only gives us 10 results. for more we need to select &continue
                next_item = continuation.get("clcontinue")
                new_url = url + f'&continue={continuation.get("continue")}&clcontinue={next_item}'
                parsed = json.loads(http.get(new_url).content)
                category_path = parsed.get("query").get("pages").get(page_id).get("categories")
                for categories in category_path:
                    category_list.append(categories.get("title").replace("Category:", ""))   
                continuation = parsed.get("continue") 
            category_list.append(suffix)    
            band_dict[band] = category_list 
            
    #### timer for final print
    elapsed_time = time.time() - time_before
    print(f"this approach took {elapsed_time} seconds for a total of {len(band_list)} bands")
    return band_dict, not_found


def find_page_id_cat(base_url, band, http):
    """
    a helper function that finds the page id of a given wikipedia article. 
    Additionally it adds suffixes to avoid ambivalent names or unwanted redirects such as 'Air', or 'Foals' for example
    """
    
    variations = ['_(band)', '_(musician)', '_(singer)', ''] #could include _(rapper) but it's rare and would slow down the algo
    for variation in variations:
        url = base_url + f'&titles={band}{variation}'
        response = http.get(url)
        parsed = json.loads(response.content)
        page_id = [*parsed.get("query").get("pages")][0]
        if page_id != "-1":
            return page_id, url, parsed, variation
    return page_id, url, None, variation

# %%
band_dict_cat, not_found = scrape_categories(bands[2000:2500])
print("Here are the results of the algorithm with redirect:\n\n")
print(f"it hasn't found the following {len(not_found)} bands: \n", not_found, "\n")
print(f"it has found categories for {len(band_dict_cat)} bands. Here they are...\n")
pp.pprint(band_dict_cat)
# Out:
# this approach took 472.6943669319153 seconds for a total of 500 bands
# Here are the results of the algorithm with redirect:
#
#
# it hasn't found the following 167 bands:
#  ['Dj_Nate', 'Dj_Nature', 'Dj_Paypal', 'Dj_Q', 'Dj_Quik', 'Dj_Quik,_Kurupt', 'Dj_Quik,_Problem', 'Dj_Rashad', 'Dj_Richard', 'Dj_Roc', 'Dj_Rude_One', 'Dj_Shadow', 'Dj_Signify', 'Dj_Snake', 'Dj_Sotofett', 'Dj_Spinn', 'Dj_Spinna', 'Dj_Spoko', 'Dj_Spooky,_Killah_Priest,_Ward_29', 'Dj_Spooky,_Scanner', 'Dj_Sprinkles', 'Dj_T.', 'Dj_Target,_Riko', 'Dj_Zeph', 'Djds', 'Dlek', 'Dm_Stith', 'Dm-Funk', 'Dm-Funk,_Steve_Arrington', 'Dodsferd', 'Dog_Shredder', 'Doley_Bernays', 'Dolphins_Into_The_Future', 'Dominik_Eulberg', 'Domo_Genesis,_The_Alchemist', 'Don_Trip,_Starlito', 'Donato_Dozzy', 'Donato_Dozzy,_Nuel', 'Donmonique', 'Donnacha_Costello', 'Donnie_%26_Joe_Emerson', 'Donnie_Trumpet_%26_The_Social_Experiment', 'Dorine_Muraille', 'Doris_Henson', 'Double_Leopards', 'Doubled_Yellow_Swans', 'Doug_Hilsinger,_Caroleen_Beatty', 'Doug_Hream_Blunt', 'Doug_Randle', 'Downliners_Sekt', 'Dr._Mix_And_The_Remix', 'Dr._Yen_Lo', 'Dragged_By_Horses', 'Dragged_Into_Sunlight_/_Gnaw_Their_Tongues', 'Drainolith', 'Drake,_Future', 'Drawing_Voices', 'Drc_Music', 'Drcarlsonalbion', 'Dreamers_Of_The_Ghetto', 'Dredd_Foole', 'Drew_Mcdowall', 'Drivan', 'Droop_Capone', 'Dropxlife', 'Drug_Rug', 'Dub_Colossus', 'Dub_Narcotic', 'Dunkelziffer', 'Duo505', 'Duran_Duran_Duran', 'Dutch_Dub', 'Dutch_E_Germ', 'Dva_[Hi:Emotions]', 'Dwarr', 'Dwayne_Sodahberk', 'Dyke_Drama', 'Dylan_Ettinger', 'Dylan_Leblanc', 'Dz_Deathrays', 'E-40,_Too_$Hort', 'Eadonmm', 'Ear_Pwr', 'Earl_Zinger', 'Early_Day_Miners,_Unwed_Sailor', 'Earth,_Roots_And_Water', 'Earthly', 'Eat_Skull', 'Ecstatic_Sunshine', 'Ecstatic_Vision', 'Efdemin', 'Ekkehard_Ehlers,_Joseph_Suchy,_Franz_Hautzinger', 'Ekkehard_Ehlers,_Paul_Wirkus', 'Ekkehard_Ehlers,_Stephan_Mathieu', 'El_Vy', 'Elder_Ones', 'Elders_Of_Zion', 'Eleanoora_Rosenholm', 'Electric_Birds', 'Electric_Sunset', 'Electric_Turn_To_Me', 'Electric_Wrms', 'Elektro4', 'Eleven_Tigers', 'Elijah_%26_Skilliam', 'Elisa_Ambrogio', 'Elton_Dean_%26_Mark_Hewins', 'Elvis_Costello,_The_Imposters', 'Elvis_Costello,_The_Roots', 'Elvis_Perkins_In_Dearland', 'Elvis_Perkins_In_Dearland,_Elvis_Perkins', 'Emeli_Sand', 'Emerald_Down', 'Emilana_Torrini', 'Emily_Reo', 'Empty_Flowers', 'Emptymansions', 'Endochine', 'Ensemble_Dal_Niente,_Deerhoof', 'Ensemble_Pearl', "Eric'S_Trip", 'Erika_Spring', 'Erland_%26_The_Carnival', 'Erlend_Ye', 'Ernest_Gonzales', 'Esben_And_The_Witch', 'Esg', 'Estasy', 'Eternal_Tapestry', 'Eternal_Tapestry,_Sun_Araw', 'Ethan_Rose', 'Etienne_Jaumet', 'Eugene_Mcdaniels', 'Eugene_Mcguinness', 'Euphone', 'Evan_Caminiti', 'Evan_Voytas', 'Everybody_Uh_Oh', 'Everybody_Was_In_The_French_Resistance...Now!', 'Ex_Cops', 'Ex-Boyfriends', 'Ex-Cult', 'Expensive_Looks', 'Experimental_Dental_School', 'Exploding_Star_Orchestra', 'Explosion_Robinson', 'Explosions_In_The_Sky,_David_Wingo', 'Ez_T', 'F_Ingers', 'F(X)', 'Fabulous_Diamonds', 'Facedowninshit', 'Failing_Lights', 'Fake_Boyfriend', 'Fake_Palms', 'Faltydl', 'Fan_Club_Orchestra', 'Fantmas', 'Fat_Jon_The_Ample_Soul_Physician', 'Fat_Ray_%26_Black_Milk', 'Fat_Worm_Of_Error', 'Fatal_Flying_Guilloteens', 'Father_Yod_And_The_Source_Family', "Father'S_Children", 'Faust,_Dlek', 'Fc/Kahuna', 'Fe-Mail']
#
# it has found categories for 333 bands. Here they are...
#
# {'Dj_Spooky': ['1970 births',
#                'All BLP articles lacking sources',
#                'American electronic musicians',
#                'American hip hop DJs',
#                'Articles containing video clips',
#                'Articles with hCards',
#                'BLP articles lacking sources from February 2012',
#                'Bowdoin College alumni',
#                'Commons category link is on Wikidata',
#                'European Graduate School faculty',
#                'Free Kitten members',
#                'Hip hop record producers',
#                'Illbient',
#                'Living people',
#                'Musicians from Washington, D.C.',
#                'Thirsty Ear Recordings artists',
#                'Trip hop musicians',
#                'Webarchive template wayback links',
#                'Wikipedia articles with BNF identifiers',
#                'Wikipedia articles with GND identifiers',
#                'Wikipedia articles with ISNI identifiers',
#                'Wikipedia articles with LCCN identifiers',
#                'Wikipedia articles with LNB identifiers',
#                'Wikipedia articles with MusicBrainz identifiers',
#                'Wikipedia articles with NDL identifiers',
#                'Wikipedia articles with NKC identifiers',
#                'Wikipedia articles with NTA identifiers',
#                'Wikipedia articles with SNAC-ID identifiers',
#                'Wikipedia articles with SUDOC identifiers',
#                'Wikipedia articles with ULAN identifiers',
#                'Wikipedia articles with VIAF identifiers',
#                'Wikipedia articles with WorldCat identifiers',
#                'Wikipedia external links cleanup from October 2013',
#                'Wikipedia spam cleanup from October 2013',
#                'Woodrow Wilson High School (Washington, D.C.) alumni',
#                ''],
#  'Django_Django': ['Articles with hCards',
#                    'Because Music artists',
#                    'English art rock groups',
#                    'English indie rock groups',
#                    'English psychedelic rock music groups',
#                    'Musical groups established in 2009',
#                    'Use dmy dates from February 2012',
#                    'Webarchive template wayback links',
#                    'Wikipedia articles with MusicBrainz identifiers',
#                    'Wikipedia articles with NKC identifiers',
#                    'Wikipedia articles with VIAF identifiers',
#                    'Wikipedia articles with WorldCat identifiers',
#                    ''],
#  'Dna': ['Articles with Curlie links',
#          'Articles with hAudio microformats',
#          'Articles with short description',
#          'Biotechnology',
#          'CS1 German-language sources (de)',
#          'CS1 Italian-language sources (it)',
#          'CS1 Russian-language sources (ru)',
#          'CS1 maint: ref=harv',
#          'Commons category link is on Wikidata',
#          'DNA',
#          'Featured articles',
#          'Helices',
#          'Nucleic acids',
#          'Pages including recorded pronunciations',
#          'Short description is different from Wikidata',
#          'Spoken articles',
#          'Use dmy dates from August 2018',
#          'Webarchive template archiveis links',
#          'Webarchive template wayback links',
#          'Wikipedia indefinitely move-protected pages',
#          'Wikipedia pages semi-protected against vandalism',
#          ''],
#  'Dntel': ['All BLP articles lacking sources',
#            'American electronic musicians',
#            'Articles with hCards',
#            'BLP articles lacking sources from April 2012',
#            'Commons category link from Wikidata',
#            'Intelligent dance musicians',
#            'Living people',
#            'Sub Pop artists',
#            'The Postal Service members',
#            'Wikipedia articles with ISNI identifiers',
#            'Wikipedia articles with LCCN identifiers',
#            'Wikipedia articles with MusicBrainz identifiers',
#            'Wikipedia articles with VIAF identifiers',
#            'Wikipedia articles with WorldCat identifiers',
#            'Year of birth missing (living people)',
#            ''],
#  'Do_Make_Say_Think': ['1995 establishments in Ontario',
#                        'All articles needing additional references',
#                        'Articles needing additional references from October '
#                        '2018',
#                        'Articles with hCards',
#                        'Canadian post-rock groups',
#                        'Constellation Records (Canada) artists',
#                        'Juno Award for Instrumental Album of the Year winners',
#                        'Musical groups established in 1995',
#                        'Musical groups from Toronto',
#                        'Wikipedia articles with BNF identifiers',
#                        'Wikipedia articles with LCCN identifiers',
#                        'Wikipedia articles with MusicBrainz identifiers',
#                        'Wikipedia articles with VIAF identifiers',
#                        'Wikipedia articles with WorldCat identifiers',
#                        ''],
#  'Do_Or_Die': ['All article disambiguation pages',
#                'All disambiguation pages',
#                'Disambiguation pages',
#                'Disambiguation pages with short descriptions',
#                'Short description is different from Wikidata',
#                'Use dmy dates from March 2013',
#                ''],
#  'Doctor_Rockit': ['1972 births',
#                    'All BLP articles lacking sources',
#                    'Articles with hCards',
#                    'BLP articles lacking sources from July 2014',
#                    'Commons category link is on Wikidata',
#                    'Downtempo musicians',
#                    'English electronic musicians',
#                    'English experimental musicians',
#                    'English record producers',
#                    'EngvarB from September 2014',
#                    'Intelligent dance musicians',
#                    'Living people',
#                    'Official website different in Wikidata and Wikipedia',
#                    'Remixers',
#                    'Use dmy dates from September 2014',
#                    'Wikipedia articles with BNF identifiers',
#                    'Wikipedia articles with GND identifiers',
#                    'Wikipedia articles with ISNI identifiers',
#                    'Wikipedia articles with LCCN identifiers',
#                    'Wikipedia articles with MusicBrainz identifiers',
#                    'Wikipedia articles with NKC identifiers',
#                    'Wikipedia articles with SUDOC identifiers',
#                    'Wikipedia articles with VIAF identifiers',
#                    'Wikipedia articles with WorldCat identifiers',
#                    ''],
#  'Doe_Paoro': ['1984 births',
#                '21st-century American singers',
#                '21st-century American women singers',
#                'American contraltos',
#                'American female singer-songwriters',
#                'American indie pop musicians',
#                'American indie rock musicians',
#                'American pop singers',
#                'American singer-songwriters',
#                'Articles with hCards',
#                'Commons category link is on Wikidata',
#                'Fayetteville-Manlius High School alumni',
#                'Living people',
#                'Official website different in Wikidata and Wikipedia',
#                'People from Fayetteville, New York',
#                'Webarchive template wayback links',
#                'Wikipedia articles with MusicBrainz identifiers',
#                ''],
#  'Does_It_Offend_You,_Yeah?': ['All articles with failed verification',
#                                'Articles with failed verification from January '
#                                '2009',
#                                'Articles with hCards',
#                                'Dance-punk musical groups',
#                                'English rock music groups',
#                                'EngvarB from September 2014',
#                                'Musical groups disestablished in 2012',
#                                'Musical groups established in 2006',
#                                'Musical groups from Reading, Berkshire',
#                                'Use dmy dates from September 2014',
#                                'Wikipedia articles with BNF identifiers',
#                                'Wikipedia articles with GND identifiers',
#                                'Wikipedia articles with ISNI identifiers',
#                                'Wikipedia articles with LCCN identifiers',
#                                'Wikipedia articles with MusicBrainz '
#                                'identifiers',
#                                'Wikipedia articles with NKC identifiers',
#                                'Wikipedia articles with VIAF identifiers',
#                                'Wikipedia articles with WorldCat identifiers',
#                                ''],
#  'Dog_Bite': ['All articles with dead external links',
#               'All articles with incomplete citations',
#               'All articles with unsourced statements',
#               'Animal bites',
#               'Articles with dead external links from November 2019',
#               'Articles with incomplete citations from August 2018',
#               'Articles with permanently dead external links',
#               'Articles with short description',
#               'Articles with unsourced statements from January 2018',
#               'CS1 German-language sources (de)',
#               'Canid attacks',
#               'Dog training and behavior',
#               'Dogs',
#               'Short description is different from Wikidata',
#               'Use dmy dates from November 2019',
#               'Wikipedia articles incorporating text from the Centers for '
#               'Disease Control and Prevention',
#               ''],
#  'Dogs_Die_In_Hot_Cars': ['All articles needing additional references',
#                           'Articles needing additional references from '
#                           'February 2008',
#                           'Articles with hCards',
#                           'Articles with short description',
#                           'Musical groups disestablished in 2006',
#                           'Musical groups established in 1997',
#                           'Musical groups reestablished in 2008',
#                           'People educated at Madras College',
#                           'Scottish indie rock groups',
#                           'Short description matches Wikidata',
#                           'Use British English from September 2014',
#                           'Use dmy dates from September 2014',
#                           'Wikipedia articles with ISNI identifiers',
#                           'Wikipedia articles with LCCN identifiers',
#                           'Wikipedia articles with MusicBrainz identifiers',
#                           'Wikipedia articles with VIAF identifiers',
#                           'Wikipedia articles with WorldCat identifiers',
#                           ''],
#  'Doldrums': ['1994 establishments in Virginia',
#               'American musical trios',
#               'American post-rock groups',
#               'Articles with hCards',
#               'Musical groups disestablished in 2000',
#               'Musical groups established in 1994',
#               'Musical groups from Virginia',
#               'Space rock musical groups',
#               '_(band)'],
#  'Doleful_Lions': ['American pop music groups',
#                    'Articles with hCards',
#                    'Parasol Records artists',
#                    'Wikipedia articles with LCCN identifiers',
#                    'Wikipedia articles with MusicBrainz identifiers',
#                    'Wikipedia articles with VIAF identifiers',
#                    'Wikipedia articles with WorldCat identifiers',
#                    ''],
#  'Dolly_Parton': ['1946 births',
#                   '20th-century American actresses',
#                   '20th-century American businesspeople',
#                   '20th-century American composers',
#                   '20th-century American guitarists',
#                   '20th-century American singers',
#                   '20th-century American women singers',
#                   '20th-century American women writers',
#                   '20th-century businesswomen',
#                   '21st-century American actresses',
#                   '21st-century American businesspeople',
#                   '21st-century American composers',
#                   '21st-century American non-fiction writers',
#                   '21st-century American singers',
#                   '21st-century American women singers',
#                   '21st-century American women writers',
#                   '21st-century businesswomen',
#                   'Actresses from Tennessee',
#                   'All articles containing potentially dated statements',
#                   'All articles with unsourced statements',
#                   'American conservationists',
#                   'American country singer-songwriters',
#                   'American entertainment industry businesspeople',
#                   'American female country singers',
#                   'American female guitarists',
#                   'American female pop singers',
#                   'American female singer-songwriters',
#                   'American film actresses',
#                   'American memoirists',
#                   'American musical theatre composers',
#                   'American musical theatre lyricists',
#                   'American pop singers',
#                   'American sopranos',
#                   'American street performers',
#                   'American television actresses',
#                   'American television personalities',
#                   'American voice actresses',
#                   'American women environmentalists',
#                   'American women memoirists',
#                   'American women non-fiction writers',
#                   'American women philanthropists',
#                   'Articles containing potentially dated statements from 2017',
#                   'Articles with hCards',
#                   'Articles with short description',
#                   'Articles with unsourced statements from April 2014',
#                   'Articles with unsourced statements from March 2014',
#                   'Articles with unsourced statements from March 2019',
#                   'Businesspeople from Tennessee',
#                   'CS1 maint: extra text: authors list',
#                   'CS1 maint: ref=harv',
#                   'Christians from Tennessee',
#                   'Country Music Hall of Fame inductees',
#                   'Country musicians from Tennessee',
#                   'Decca Records artists',
#                   'Dolly Parton',
#                   'Feminist musicians',
#                   'Grammy Award winners',
#                   'Grammy Lifetime Achievement Award winners',
#                   'Grand Ole Opry members',
#                   'Kennedy Center honorees',
#                   'Literacy advocates',
#                   'Living people',
#                   'Mercury Records artists',
#                   'Monument Records artists',
#                   'Music of East Tennessee',
#                   'Musicians from Appalachia',
#                   'Musicians from Tennessee',
#                   'Official website different in Wikidata and Wikipedia',
#                   'People from Sevier County, Tennessee',
#                   'People from Sevierville, Tennessee',
#                   'Philanthropists from Tennessee',
#                   'RCA Records Nashville artists',
#                   'Short description is different from Wikidata',
#                   'Songwriters from Tennessee',
#                   'Sugar Hill Records artists',
#                   'United States National Medal of Arts recipients',
#                   'Use mdy dates from July 2019',
#                   'Webarchive template wayback links',
#                   'Wikipedia articles with BIBSYS identifiers',
#                   'Wikipedia articles with BNE identifiers',
#                   'Wikipedia articles with BNF identifiers',
#                   'Wikipedia articles with CANTIC identifiers',
#                   'Wikipedia articles with CINII identifiers',
#                   'Wikipedia articles with GND identifiers',
#                   'Wikipedia articles with ISNI identifiers',
#                   'Wikipedia articles with LCCN identifiers',
#                   'Wikipedia articles with MusicBrainz identifiers',
#                   'Wikipedia articles with NKC identifiers',
#                   'Wikipedia articles with NLA identifiers',
#                   'Wikipedia articles with NTA identifiers',
#                   'Wikipedia articles with SELIBR identifiers',
#                   'Wikipedia articles with SNAC-ID identifiers',
#                   'Wikipedia articles with SUDOC identifiers',
#                   'Wikipedia articles with Trove identifiers',
#                   'Wikipedia articles with VIAF identifiers',
#                   'Wikipedia articles with WorldCat identifiers',
#                   ''],
#  'Dolorean': ['1999 establishments in Oregon',
#               'Articles with hCards',
#               'Commons category link is on Wikidata',
#               'Indie rock musical groups from Oregon',
#               'Musical groups established in 1999',
#               'Musical groups from Portland, Oregon',
#               'Partisan Records artists',
#               'Wikipedia articles with LCCN identifiers',
#               'Wikipedia articles with MusicBrainz identifiers',
#               'Wikipedia articles with VIAF identifiers',
#               'Wikipedia articles with WorldCat identifiers',
#               'Yep Roc Records artists',
#               ''],
#  'Dom': ['All articles with dead external links',
#          'All articles with unsourced statements',
#          'Articles with dead external links from September 2017',
#          'Articles with hCards',
#          'Articles with permanently dead external links',
#          'Articles with unsourced statements from March 2015',
#          'Musical groups from Massachusetts',
#          'Wikipedia articles with MusicBrainz identifiers',
#          'Wikipedia articles with NKC identifiers',
#          'Wikipedia articles with VIAF identifiers',
#          'Wikipedia articles with WorldCat-VIAF identifiers',
#          'Wikipedia articles with possible conflicts of interest from March '
#          '2015',
#          '_(band)'],
#  'Dominique_Leone': ['1973 births',
#                      '21st-century American composers',
#                      '21st-century American singers',
#                      '21st-century male singers',
#                      'American male composers',
#                      'American male singer-songwriters',
#                      'American singer-songwriters',
#                      'Articles with hCards',
#                      'Living people',
#                      'People from Dallas',
#                      'Songwriters from Texas',
#                      'Wikipedia articles with ISNI identifiers',
#                      'Wikipedia articles with LCCN identifiers',
#                      'Wikipedia articles with MusicBrainz identifiers',
#                      'Wikipedia articles with VIAF identifiers',
#                      'Wikipedia articles with WorldCat identifiers',
#                      ''],
#  'Domo_Genesis': ['1991 births',
#                   '21st-century American rappers',
#                   'African-American Christians',
#                   'African-American male rappers',
#                   'All articles with unsourced statements',
#                   'American rappers',
#                   'Articles with hCards',
#                   'Articles with unsourced statements from July 2019',
#                   'Living people',
#                   'Musicians from Hawthorne, California',
#                   'Odd Future members',
#                   'Rappers from Los Angeles',
#                   'West Coast hip hop musicians',
#                   'Wikipedia articles with BNF identifiers',
#                   'Wikipedia articles with ISNI identifiers',
#                   'Wikipedia articles with LCCN identifiers',
#                   'Wikipedia articles with MusicBrainz identifiers',
#                   'Wikipedia articles with SUDOC identifiers',
#                   'Wikipedia articles with VIAF identifiers',
#                   'Wikipedia articles with WorldCat identifiers',
#                   ''],
#  'Don_Caballero': ['All articles needing additional references',
#                    'All articles with unsourced statements',
#                    'American post-rock groups',
#                    'Articles needing additional references from November 2014',
#                    'Articles with hCards',
#                    'Articles with short description',
#                    'Articles with unsourced statements from July 2017',
#                    'CS1 maint: ref=harv',
#                    'Commons category link from Wikidata',
#                    'Indie rock musical groups from Pennsylvania',
#                    'Math rock groups',
#                    'Musical groups from Pittsburgh',
#                    'Pages using Timeline',
#                    'Post-progressive musicians',
#                    'Relapse Records artists',
#                    'Short description matches Wikidata',
#                    'Touch and Go Records artists',
#                    'Webarchive template wayback links',
#                    'Wikipedia articles with BIBSYS identifiers',
#                    'Wikipedia articles with LCCN identifiers',
#                    'Wikipedia articles with MusicBrainz identifiers',
#                    'Wikipedia articles with VIAF identifiers',
#                    'Wikipedia articles with WorldCat identifiers',
#                    ''],
#  'Don_Lennon': ['All articles with unsourced statements',
#                 'American indie rock musicians',
#                 'American male guitarists',
#                 'American male singers',
#                 'American pop singers',
#                 'American rock guitarists',
#                 'Articles with unsourced statements from March 2018',
#                 'CS1 maint: archived copy as title',
#                 'Guitarists from Massachusetts',
#                 'Living people',
#                 'Secretly Canadian artists',
#                 'Singers from Massachusetts',
#                 'Webarchive template wayback links',
#                 'Wikipedia articles with MusicBrainz identifiers',
#                 'Year of birth missing (living people)',
#                 ''],
#  'Don_Zientara': ['American audio engineers',
#                   'American male musicians',
#                   'American musicians',
#                   'American record producers',
#                   'Articles with hCards',
#                   'Living people',
#                   'Production discographies',
#                   'Rock music discographies',
#                   'Use mdy dates from October 2014',
#                   'Wikipedia articles with MusicBrainz identifiers',
#                   'Year of birth missing (living people)',
#                   ''],
#  'Donna_Summer': ['1948 births',
#                   '2012 deaths',
#                   '20th-century American actresses',
#                   '20th-century American singers',
#                   '20th-century American women singers',
#                   '20th-century Methodists',
#                   '21st-century American actresses',
#                   '21st-century American singers',
#                   '21st-century American women singers',
#                   '21st-century Methodists',
#                   'Actresses from Boston',
#                   'African-American Methodists',
#                   'African-American actresses',
#                   'African-American female singers',
#                   'African-American rock singers',
#                   'All articles needing additional references',
#                   'All articles that are excessively detailed',
#                   'All articles with dead external links',
#                   'All articles with style issues',
#                   'All articles with unsourced statements',
#                   'American Methodists',
#                   'American dance musicians',
#                   'American disco musicians',
#                   'American disco singers',
#                   'American expatriates in Austria',
#                   'American expatriates in Germany',
#                   'American female pop singers',
#                   'American female rock singers',
#                   'American female singer-songwriters',
#                   'American film actresses',
#                   'American pop singers',
#                   'American rhythm and blues singers',
#                   'American rock songwriters',
#                   'American singer-songwriters',
#                   'American soul singers',
#                   'American television actresses',
#                   'American women in electronic music',
#                   'Articles containing German-language text',
#                   'Articles needing additional references from June 2014',
#                   'Articles with dead external links from December 2018',
#                   'Articles with dead external links from May 2016',
#                   'Articles with hCards',
#                   'Articles with permanently dead external links',
#                   'Articles with short description',
#                   'Articles with unsourced statements from July 2014',
#                   'Articles with unsourced statements from July 2015',
#                   'Articles with unsourced statements from June 2019',
#                   'Articles with unsourced statements from May 2015',
#                   'Articles with unsourced statements from October 2016',
#                   'Atlantic Records artists',
#                   'Burials in Tennessee',
#                   'Casablanca Records artists',
#                   'Commons category link is on Wikidata',
#                   'Crossover (music)',
#                   'Deaths from cancer in Florida',
#                   'Deaths from lung cancer',
#                   'Donna Summer',
#                   'Geffen Records artists',
#                   'German-language singers',
#                   'Grammy Award winners',
#                   'Grammy Award winners for dance and electronic music',
#                   'Mercury Records artists',
#                   'Musicians from Boston',
#                   'Musicians from Nashville, Tennessee',
#                   'People from Mission Hill, Boston',
#                   'People from Naples, Florida',
#                   'Short description is different from Wikidata',
#                   'Singers from California',
#                   'Singers from Florida',
#                   'Songwriters from California',
#                   'Songwriters from Florida',
#                   'Songwriters from Massachusetts',
#                   'Songwriters from Tennessee',
#                   'Turner Classic Movies person ID same as Wikidata',
#                   'Use mdy dates from May 2013',
#                   'Webarchive template wayback links',
#                   'Wikipedia articles that are excessively detailed from '
#                   'December 2014',
#                   'Wikipedia articles with BIBSYS identifiers',
#                   'Wikipedia articles with BNE identifiers',
#                   'Wikipedia articles with BNF identifiers',
#                   'Wikipedia articles with GND identifiers',
#                   'Wikipedia articles with ISNI identifiers',
#                   'Wikipedia articles with LCCN identifiers',
#                   'Wikipedia articles with MusicBrainz identifiers',
#                   'Wikipedia articles with NKC identifiers',
#                   'Wikipedia articles with NLA identifiers',
#                   'Wikipedia articles with NLK identifiers',
#                   'Wikipedia articles with NSK identifiers',
#                   'Wikipedia articles with NTA identifiers',
#                   'Wikipedia articles with RERO identifiers',
#                   'Wikipedia articles with SBN identifiers',
#                   'Wikipedia articles with SNAC-ID identifiers',
#                   'Wikipedia articles with SUDOC identifiers',
#                   'Wikipedia articles with VIAF identifiers',
#                   'Wikipedia articles with WorldCat identifiers',
#                   'Wikipedia articles with style issues from December 2014',
#                   ''],
#  'Donny_Mccaslin': ['1966 births',
#                     '21st-century American male musicians',
#                     '21st-century saxophonists',
#                     'American jazz saxophonists',
#                     'American male saxophonists',
#                     'Arabesque Records artists',
#                     'Articles with hCards',
#                     'CS1 maint: archived copy as title',
#                     'Criss Cross Jazz artists',
#                     'Jazz musicians from California',
#                     'Living people',
#                     'Male jazz musicians',
#                     'Motéma Music artists',
#                     'Musicians from Santa Cruz, California',
#                     'Steps Ahead members',
#                     'Sunnyside Records artists',
#                     'Wikipedia articles with BNF identifiers',
#                     'Wikipedia articles with GND identifiers',
#                     'Wikipedia articles with ISNI identifiers',
#                     'Wikipedia articles with LCCN identifiers',
#                     'Wikipedia articles with MusicBrainz identifiers',
#                     'Wikipedia articles with NKC identifiers',
#                     'Wikipedia articles with SUDOC identifiers',
#                     'Wikipedia articles with VIAF identifiers',
#                     'Wikipedia articles with WorldCat identifiers',
#                     ''],
#  'Donovan': ['1946 births',
#              '20th-century Scottish musicians',
#              '20th-century Scottish singers',
#              '21st-century Scottish singers',
#              'All BLP articles lacking sources',
#              'All articles with unsourced statements',
#              'Articles with hCards',
#              'Articles with short description',
#              'Articles with unsourced statements from August 2014',
#              'Articles with unsourced statements from December 2019',
#              'Articles with unsourced statements from February 2013',
#              'Articles with unsourced statements from February 2016',
#              'Articles with unsourced statements from March 2010',
#              'Articles with unsourced statements from May 2014',
#              'BLP articles lacking sources from September 2011',
#              'British Invasion artists',
#              'British folk-pop singers',
#              'British folk rock musicians',
#              'British harmonica players',
#              'CS1 maint: BOT: original-url status unknown',
#              'Dawn Records artists',
#              'EngvarB from February 2016',
#              'Epic Records artists',
#              'Fingerstyle guitarists',
#              'Hickory Records artists',
#              'Living people',
#              'Musicians from Glasgow',
#              'Pages using deprecated image syntax',
#              'People from Hatfield, Hertfordshire',
#              'People from Maryhill',
#              'People with polio',
#              'Psychedelic folk musicians',
#              'Psychedelic rock musicians',
#              'Pye Records artists',
#              'Rak Records artists',
#              'Scottish autobiographers',
#              'Scottish buskers',
#              'Scottish folk singers',
#              'Scottish male singers',
#              'Scottish people of Irish descent',
#              'Scottish pop singers',
#              'Scottish record producers',
#              'Scottish rock singers',
#              'Scottish singer-songwriters',
#              'Scottish songwriters',
#              'Short description matches Wikidata',
#              'Transcendental Meditation practitioners',
#              'Use dmy dates from February 2016',
#              'Wikipedia articles needing clarification from February 2013',
#              'Wikipedia articles with BNE identifiers',
#              'Wikipedia articles with BNF identifiers',
#              'Wikipedia articles with GND identifiers',
#              'Wikipedia articles with ISNI identifiers',
#              'Wikipedia articles with LCCN identifiers',
#              'Wikipedia articles with MusicBrainz identifiers',
#              'Wikipedia articles with NDL identifiers',
#              'Wikipedia articles with NKC identifiers',
#              'Wikipedia articles with SELIBR identifiers',
#              'Wikipedia articles with SUDOC identifiers',
#              'Wikipedia articles with VIAF identifiers',
#              'Wikipedia articles with WorldCat identifiers',
#              ''],
#  'Doom': ['All article disambiguation pages',
#           'All disambiguation pages',
#           'Disambiguation pages',
#           'Disambiguation pages with short descriptions',
#           'Disambiguation pages with surname-holder lists',
#           'Place name disambiguation pages',
#           '_(band)'],
#  'Doomriders': ['Articles with hCards',
#                 'Deathwish Inc. artists',
#                 'Hardcore punk groups from Massachusetts',
#                 'Wikipedia articles with LCCN identifiers',
#                 'Wikipedia articles with MusicBrainz identifiers',
#                 'Wikipedia articles with VIAF identifiers',
#                 'Wikipedia articles with WorldCat identifiers',
#                 ''],
#  'Doomtree': ['1964 births',
#               '20th-century American drummers',
#               '20th-century American guitarists',
#               'All BLP articles lacking sources',
#               'American heavy metal bass guitarists',
#               'American heavy metal drummers',
#               'American male bass guitarists',
#               'American male drummers',
#               'American people of Italian descent',
#               'Articles with hCards',
#               'Articles with short description',
#               'BLP articles lacking sources from July 2009',
#               'Danzig (band) members',
#               'Horror punk musicians',
#               'Living people',
#               'Lodi High School (New Jersey) alumni',
#               'People from Lodi, New Jersey',
#               'Samhain (band) members',
#               'Short description matches Wikidata',
#               'The Undead members',
#               'Wikipedia articles with MusicBrainz identifiers',
#               '_(band)'],
#  'Dope_Body': ['American noise rock music groups',
#                'Articles with hCards',
#                'Drag City (record label) artists',
#                'Musical groups established in 2008',
#                'Musical groups from Baltimore',
#                'Rock music groups from Maryland',
#                'Wikipedia articles with MusicBrainz identifiers',
#                ''],
#  'Dornik': ['1990 births',
#             '21st-century English singers',
#             '21st-century male singers',
#             'All stub articles',
#             'Articles with hCards',
#             'Articles with short description',
#             'Articles with short description added by PearBOT 5',
#             'Black British male singers',
#             'British contemporary R&B singers',
#             'British house musicians',
#             'British singer stubs',
#             'British soul singers',
#             'Living people',
#             'Short description with empty Wikidata description',
#             'Singers from London',
#             'Use dmy dates from July 2018',
#             'Wikipedia articles with VIAF identifiers',
#             'Wikipedia articles with WorldCat identifiers',
#             ''],
#  'Doseone': ['1977 births',
#              'All BLP articles lacking sources',
#              'All articles with unsourced statements',
#              'American hip hop record producers',
#              'American male rappers',
#              'Anticon',
#              'Articles with hCards',
#              'Articles with unsourced statements from October 2015',
#              'BLP articles lacking sources from May 2015',
#              'Lex Records artists',
#              'Living people',
#              'Midwest hip hop musicians',
#              'Musicians from Cincinnati',
#              'Rappers from Ohio',
#              'Underground rappers',
#              'Wikipedia articles with MusicBrainz identifiers',
#              'Wikipedia articles with VIAF identifiers',
#              'Wikipedia articles with WorldCat-VIAF identifiers',
#              ''],
#  'Dosh': ['1972 births',
#           'American electronic musicians',
#           'American multi-instrumentalists',
#           'American percussionists',
#           'Anticon',
#           'Articles with hCards',
#           'Living people',
#           'Musicians from Minneapolis',
#           'Wikipedia articles with MusicBrainz identifiers',
#           '_(musician)'],
#  'Doss': ['All article disambiguation pages',
#           'All disambiguation pages',
#           'Disambiguation pages',
#           'Disambiguation pages with short descriptions',
#           'Short description is different from Wikidata',
#           ''],
#  'Dot_Allison': ['1969 births',
#                  '21st-century women singers',
#                  'All BLP articles lacking sources',
#                  'All articles with unsourced statements',
#                  'Articles with hCards',
#                  'Articles with unsourced statements from June 2011',
#                  'BLP articles lacking sources from August 2010',
#                  'British women in electronic music',
#                  'Living people',
#                  'Musicians from Edinburgh',
#                  'Official website different in Wikidata and Wikipedia',
#                  'Scottish female singers',
#                  'Scottish songwriters',
#                  'Trip hop musicians',
#                  'Use dmy dates from December 2019',
#                  'Wikipedia articles with BNF identifiers',
#                  'Wikipedia articles with ISNI identifiers',
#                  'Wikipedia articles with MusicBrainz identifiers',
#                  'Wikipedia articles with VIAF identifiers',
#                  'Wikipedia articles with WorldCat identifiers',
#                  ''],
#  'Double_Dagger': ['2002 establishments in Maryland',
#                    'American post-punk music groups',
#                    'Articles with hCards',
#                    'Musical groups disestablished in 2011',
#                    'Musical groups established in 2002',
#                    'Musical groups from Baltimore',
#                    'Pages using Template:Infobox musical artist with unknown '
#                    'parameters',
#                    'Rock music groups from Maryland',
#                    'Wikipedia articles with MusicBrainz identifiers',
#                    '_(band)'],
#  'Doug_Martsch': ['1969 births',
#                   '20th-century American guitarists',
#                   '20th-century American male musicians',
#                   'All stub articles',
#                   'American male guitarists',
#                   'American male singers',
#                   'American rock guitarist stubs',
#                   'American rock guitarists',
#                   'American rock singer stubs',
#                   'Articles with hCards',
#                   'Built to Spill members',
#                   'Guitarists from Idaho',
#                   'K Records artists',
#                   'Living people',
#                   'Musicians from Boise, Idaho',
#                   'People from Twin Falls, Idaho',
#                   'Up Records',
#                   'Wikipedia articles with GND identifiers',
#                   'Wikipedia articles with ISNI identifiers',
#                   'Wikipedia articles with LCCN identifiers',
#                   'Wikipedia articles with MusicBrainz identifiers',
#                   'Wikipedia articles with VIAF identifiers',
#                   'Wikipedia articles with WorldCat identifiers',
#                   ''],
#  'Doug_Paisley': ['Articles with hCards',
#                   'Canadian alternative country singers',
#                   'Canadian country singer-songwriters',
#                   'Canadian male singer-songwriters',
#                   'Living people',
#                   'Musicians from Toronto',
#                   'Wikipedia articles with ISNI identifiers',
#                   'Wikipedia articles with MusicBrainz identifiers',
#                   'Wikipedia articles with VIAF identifiers',
#                   'Wikipedia articles with WorldCat identifiers',
#                   'Year of birth missing (living people)',
#                   ''],
#  'Doughboyz_Cashout': ['American record labels',
#                        'Companies based in Atlanta',
#                        'Gangsta rap record labels',
#                        'Hip hop record labels',
#                        'Jeezy',
#                        'Labels distributed by Warner Music Group',
#                        'Record labels established in 1998',
#                        'Vanity record labels',
#                        ''],
#  'Doveman': ['1981 births',
#              '21st-century American keyboardists',
#              'Antony and the Johnsons members',
#              'Articles with hCards',
#              'Articles with short description',
#              'Living people',
#              'Musicians from Vermont',
#              'Pupils of Maria Curcio',
#              'The Gloaming members',
#              'Wikipedia articles with ISNI identifiers',
#              'Wikipedia articles with LCCN identifiers',
#              'Wikipedia articles with MusicBrainz identifiers',
#              'Wikipedia articles with VIAF identifiers',
#              'Wikipedia articles with WorldCat identifiers',
#              ''],
#  'Doves': ['Articles with hCards',
#            'CS1 errors: external links',
#            'English alternative rock groups',
#            'Heavenly Records artists',
#            'Musical groups established in 1998',
#            'Musical groups from Cheshire',
#            'Post-Britpop groups',
#            'Use dmy dates from March 2020',
#            'Webarchive template wayback links',
#            'Wikipedia articles with BIBSYS identifiers',
#            'Wikipedia articles with GND identifiers',
#            'Wikipedia articles with LCCN identifiers',
#            'Wikipedia articles with MusicBrainz identifiers',
#            'Wikipedia articles with NKC identifiers',
#            'Wikipedia articles with VIAF identifiers',
#            'Wikipedia articles with WorldCat-VIAF identifiers',
#            '_(band)'],
#  'Downfall_Of_Gaia': ['2008 establishments in Germany',
#                       'Articles with hCards',
#                       'CS1 German-language sources (de)',
#                       'Crust and d-beat groups',
#                       'German black metal musical groups',
#                       'German doom metal musical groups',
#                       'German hardcore punk groups',
#                       'German heavy metal musical groups',
#                       'German post-rock groups',
#                       'Metal Blade Records artists',
#                       'Musical groups established in 2008',
#                       'Musical quartets',
#                       'Post-metal musical groups',
#                       'Sludge metal musical groups',
#                       'Wikipedia articles with BNF identifiers',
#                       'Wikipedia articles with LCCN identifiers',
#                       'Wikipedia articles with MusicBrainz identifiers',
#                       'Wikipedia articles with NKC identifiers',
#                       'Wikipedia articles with VIAF identifiers',
#                       'Wikipedia articles with WorldCat identifiers',
#                       ''],
#  'Downtown_Boys': ['American punk rock groups',
#                    'Articles with hCards',
#                    'Don Giovanni Records artists',
#                    'Musical groups established in 2011',
#                    'Musical groups from Providence, Rhode Island',
#                    'Wikipedia articles with MusicBrainz identifiers',
#                    'Wikipedia articles with VIAF identifiers',
#                    'Wikipedia articles with WorldCat identifiers',
#                    '_(band)'],
#  'Dr._Dog': ['1999 establishments in Pennsylvania',
#              'American indie folk groups',
#              'American psychedelic rock music groups',
#              'Articles with hCards',
#              'Articles with short description',
#              'Commons category link from Wikidata',
#              'Musical groups established in 1999',
# ...
#            'Pages using multiple image with auto scaled images',
#            'Pharaohs',
#            'Positions of authority',
#            'Royal titles',
#            'Short description is different from Wikidata',
#            'Titles of national or ethnic leadership',
#            'Torah monarchs',
#            'Torah people',
#            'Wikipedia articles with BNE identifiers',
#            'Wikipedia articles with BNF identifiers',
#            'Wikipedia articles with GND identifiers',
#            'Wikipedia articles with LCCN identifiers',
#            'Wikipedia articles with SUDOC identifiers',
#            'Wikipedia indefinitely semi-protected pages',
#            ''],
#  'Faraquet': ['All stub articles',
#               'American post-hardcore musical groups',
#               'Articles with hCards',
#               'Math rock groups',
#               'Musical groups from Washington, D.C.',
#               'United States rock musical group stubs',
#               'Wikipedia articles with LCCN identifiers',
#               'Wikipedia articles with MusicBrainz identifiers',
#               'Wikipedia articles with VIAF identifiers',
#               'Wikipedia articles with WorldCat identifiers',
#               ''],
#  'Farben': ['All article disambiguation pages',
#             'All disambiguation pages',
#             'Disambiguation pages',
#             'Disambiguation pages with short descriptions',
#             'Short description is different from Wikidata',
#             ''],
#  'Fat_Trel': ['1990 births',
#               '21st-century American male musicians',
#               '21st-century American rappers',
#               'African-American male rappers',
#               'All BLP articles lacking sources',
#               'All articles lacking reliable references',
#               'American hip hop singers',
#               'Articles lacking reliable references from June 2014',
#               'Articles with hCards',
#               'Articles with multiple maintenance issues',
#               'Articles with short description',
#               'BLP articles lacking sources from June 2014',
#               'Living people',
#               'Rappers from Washington, D.C.',
#               'Wikipedia articles with LCCN identifiers',
#               'Wikipedia articles with MusicBrainz identifiers',
#               'Wikipedia articles with VIAF identifiers',
#               'Wikipedia articles with WorldCat identifiers',
#               ''],
#  'Fat_White_Family': ['2011 establishments in the United Kingdom',
#                       'Articles with hCards',
#                       'Commons category link is on Wikidata',
#                       'English experimental musical groups',
#                       'English post-punk music groups',
#                       'English rock music groups',
#                       'Fat Possum Records artists',
#                       'Musical groups established in 2011',
#                       'People from Peckham',
#                       'Sibling musical groups',
#                       'Use British English from June 2016',
#                       'Use dmy dates from June 2016',
#                       'Wikipedia articles with LCCN identifiers',
#                       'Wikipedia articles with MusicBrainz identifiers',
#                       'Wikipedia articles with VIAF identifiers',
#                       'Wikipedia articles with WorldCat identifiers',
#                       ''],
#  'Fatboy_Slim': ['1963 births',
#                  'All articles with dead external links',
#                  'All articles with unsourced statements',
#                  'Alumni of the University of Brighton',
#                  'Articles with dead external links from December 2019',
#                  'Articles with hCards',
#                  'Articles with permanently dead external links',
#                  'Articles with short description',
#                  'Articles with unsourced statements from July 2010',
#                  'Articles with unsourced statements from March 2018',
#                  'Astralwerks artists',
#                  'Big beat musicians',
#                  'Breakbeat musicians',
#                  'Brit Award winners',
#                  'CS1: long volume value',
#                  'CS1 maint: archived copy as title',
#                  'Commons category link is on Wikidata',
#                  'DJs from London',
#                  'English electronic musicians',
#                  'English football chairmen and investors',
#                  'English house musicians',
#                  'EngvarB from November 2015',
#                  'Grammy Award winners',
#                  'Ivor Novello Award winners',
#                  'Living people',
#                  'MTV EMA winners',
#                  'Musicians from Brighton and Hove',
#                  'Musicians from London',
#                  'NME Awards winners',
#                  'Pages with citations having bare URLs',
#                  'Pages with citations lacking titles',
#                  'People educated at Reigate Grammar School',
#                  'People from Bromley',
#                  'People from Hove',
#                  'Remixers',
#                  'Short description matches Wikidata',
#                  'The Housemartins members',
#                  'Use dmy dates from February 2020',
#                  'Wikipedia articles with BNE identifiers',
#                  'Wikipedia articles with BNF identifiers',
#                  'Wikipedia articles with CANTIC identifiers',
#                  'Wikipedia articles with GND identifiers',
#                  'Wikipedia articles with ISNI identifiers',
#                  'Wikipedia articles with LCCN identifiers',
#                  'Wikipedia articles with MusicBrainz identifiers',
#                  'Wikipedia articles with NKC identifiers',
#                  'Wikipedia articles with NTA identifiers',
#                  'Wikipedia articles with SUDOC identifiers',
#                  'Wikipedia articles with VIAF identifiers',
#                  'Wikipedia articles with WorldCat identifiers',
#                  ''],
#  'Father': ['All articles needing additional references',
#             'Articles needing additional references from December 2008',
#             'Articles with hCards',
#             'Croatian rock music groups',
#             'Musical groups established in 2000',
#             'Official website different in Wikidata and Wikipedia',
#             'Use dmy dates from June 2015',
#             'Wikipedia articles with MusicBrainz identifiers',
#             'Wikipedia articles with VIAF identifiers',
#             'Wikipedia articles with WorldCat identifiers',
#             '_(band)'],
#  'Father_John_Misty': ['1981 births',
#                        '21st-century American drummers',
#                        '21st-century American singers',
#                        'American agnostics',
#                        'American atheists',
#                        'American drummers',
#                        'American male drummers',
#                        'American male singer-songwriters',
#                        'American singer-songwriters',
#                        'Articles with hCards',
#                        'Articles with short description',
#                        'Bella Union artists',
#                        'CS1 Swedish-language sources (sv)',
#                        'Critics of religions',
#                        'Fleet Foxes members',
#                        'Grammy Award winners',
#                        'Indie folk musicians',
#                        'Josh Tillman',
#                        'Living people',
#                        'Musicians from Maryland',
#                        'Musicians from Seattle',
#                        'Nyack College alumni',
#                        'People from Rockville, Maryland',
#                        'Short description matches Wikidata',
#                        'Singers from Washington (state)',
#                        'Songwriters from Washington (state)',
#                        'Third Man Records artists',
#                        'Use mdy dates from April 2020',
#                        'Western Vinyl artists',
#                        'Wikipedia articles with BNF identifiers',
#                        'Wikipedia articles with GND identifiers',
#                        'Wikipedia articles with ISNI identifiers',
#                        'Wikipedia articles with LCCN identifiers',
#                        'Wikipedia articles with MusicBrainz identifiers',
#                        'Wikipedia articles with SNAC-ID identifiers',
#                        'Wikipedia articles with VIAF identifiers',
#                        'Wikipedia articles with WorldCat identifiers',
#                        ''],
#  'Fatima': ['All article disambiguation pages',
#             'All disambiguation pages',
#             'Disambiguation pages',
#             'Disambiguation pages with short descriptions',
#             'Disambiguation pages with surname-holder lists',
#             'Place name disambiguation pages',
#             'Short description is different from Wikidata',
#             ''],
#  'Fatima_Al_Qadiri': ['1981 births',
#                       'Articles containing Arabic-language text',
#                       'Articles with hCards',
#                       'Articles with short description',
#                       'Articles with short description added by PearBOT 5',
#                       'CS1 maint: archived copy as title',
#                       'Expatriates in Germany',
#                       'Hyperdub artists',
#                       'Kuwaiti artists',
#                       'Kuwaiti electronic musicians',
#                       'Kuwaiti women artists',
#                       'Living people',
#                       'Performance artists',
#                       'Use dmy dates from April 2016',
#                       'Webarchive template wayback links',
#                       'Wikipedia articles with GND identifiers',
#                       'Wikipedia articles with MusicBrainz identifiers',
#                       'Wikipedia articles with VIAF identifiers',
#                       'Wikipedia articles with WorldCat identifiers',
#                       'Women in electronic music',
#                       ''],
#  'Fatoumata_Diawara': ['1982 births',
#                        '21st-century women singers',
#                        'All articles with unsourced statements',
#                        'Articles with hCards',
#                        'Articles with unsourced statements from February 2020',
#                        'CS1 maint: archived copy as title',
#                        'Commons category link from Wikidata',
#                        'Ivorian female singers',
#                        'Living people',
#                        'Malian activists',
#                        'Malian emigrants to France',
#                        'Malian female singers',
#                        "Malian women's rights activists",
#                        'People from Bamako',
#                        'Webarchive template wayback links',
#                        'Wikipedia articles with BNF identifiers',
#                        'Wikipedia articles with GND identifiers',
#                        'Wikipedia articles with ISNI identifiers',
#                        'Wikipedia articles with LCCN identifiers',
#                        'Wikipedia articles with MusicBrainz identifiers',
#                        'Wikipedia articles with SUDOC identifiers',
#                        'Wikipedia articles with VIAF identifiers',
#                        'Wikipedia articles with WorldCat identifiers',
#                        ''],
#  'Faultline': ['All articles lacking in-text citations',
#                'All articles with unsourced statements',
#                'Articles lacking in-text citations from May 2020',
#                'Articles with hCards',
#                'Articles with short description',
#                'Articles with unsourced statements from December 2012',
#                'English electronic musicians',
#                'EngvarB from September 2014',
#                'Intelligent dance musicians',
#                'Living people',
#                'Use dmy dates from September 2014',
#                'Wikipedia articles with MusicBrainz identifiers',
#                'Year of birth missing (living people)',
#                '_(musician)'],
#  'Faun_Fables': ['1999 establishments in California',
#                  'All articles needing additional references',
#                  'Articles needing additional references from September 2014',
#                  'Articles with hCards',
#                  'Drag City (record label) artists',
#                  'Freak folk',
#                  'Musical groups established in 1999',
#                  'Musical groups from Oakland, California',
#                  'Psychedelic folk groups',
#                  'Wikipedia articles with MusicBrainz identifiers',
#                  'Wikipedia articles with VIAF identifiers',
#                  'Wikipedia articles with WorldCat identifiers',
#                  ''],
#  'Faunts': ['2000 establishments in Alberta',
#             'All articles covered by WikiProject Wikify',
#             'All pages needing cleanup',
#             'Articles covered by WikiProject Wikify from July 2016',
#             'Articles with hCards',
#             'Canadian experimental musical groups',
#             'Canadian indie rock groups',
#             'Canadian post-rock groups',
#             'Dream pop musical groups',
#             'Musical groups established in 2000',
#             'Musical groups from Edmonton',
#             'Post-punk revival music groups',
#             'Wikipedia articles with MusicBrainz identifiers',
#             'Wikipedia articles with VIAF identifiers',
#             'Wikipedia articles with WorldCat identifiers',
#             'Wikipedia introduction cleanup from July 2016',
#             ''],
#  'Faust': ['All articles needing additional references',
#            'All articles with unsourced statements',
#            'Articles needing additional references from February 2010',
#            'Articles with hCards',
#            'Articles with short description',
#            'Articles with unsourced statements from July 2010',
#            'Commons category link is on Wikidata',
#            'Faust (band)',
#            'German experimental musical groups',
#            'Krautrock musical groups',
#            'Musical groups established in 1971',
#            'Short description matches Wikidata',
#            'Use dmy dates from July 2014',
#            'Virgin Records artists',
#            'Wikipedia articles with BNF identifiers',
#            'Wikipedia articles with GND identifiers',
#            'Wikipedia articles with LCCN identifiers',
#            'Wikipedia articles with MusicBrainz identifiers',
#            'Wikipedia articles with SUDOC identifiers',
#            'Wikipedia articles with VIAF identifiers',
#            'Wikipedia articles with WorldCat identifiers',
#            '_(band)'],
#  'Favourite_Sons': ['All articles with dead external links',
#                     'Articles with dead external links from August 2019',
#                     'Articles with permanently dead external links',
#                     'Indie rock musical groups from New York (state)',
#                     'Musical groups from Brooklyn',
#                     ''],
#  'Feadz': ['Articles with hCards',
#            'Articles with short description',
#            'Articles with short description added by PearBOT 5',
#            'CS1 maint: archived copy as title',
#            'Electronica musicians',
#            'French dance musicians',
#            'French electronic musicians',
#            'French house musicians',
#            'Living people',
#            'Wikipedia articles with BNF identifiers',
#            'Wikipedia articles with ISNI identifiers',
#            'Wikipedia articles with LCCN identifiers',
#            'Wikipedia articles with MusicBrainz identifiers',
#            'Wikipedia articles with SUDOC identifiers',
#            'Wikipedia articles with VIAF identifiers',
#            'Wikipedia articles with WorldCat identifiers',
#            'Year of birth missing (living people)',
#            '']}

# %%
df_cat = pd.DataFrame(pd.Series(band_dict_cat).values, pd.Series(band_dict_cat).index)
df_cat.rename(columns={0: "categories"}, inplace=True)
df_cat.loc[:, 'suffix'] = df_cat.categories.map(lambda x: x[-1])
df_cat.loc[:, 'categories'] = df_cat.categories.map(lambda x: x[:-1])
df_cat.index.name = "artist"
df_cat
# Out:
#                                                           categories   suffix
# artist
# Dj_Spooky          [1970 births, All BLP articles lacking sources...
# Django_Django      [Articles with hCards, Because Music artists, ...
# Dna                [Articles with Curlie links, Articles with hAu...
# Dntel              [All BLP articles lacking sources, American el...
# Do_Make_Say_Think  [1995 establishments in Ontario, All articles ...
# ...                                                              ...      ...
# Faun_Fables        [1999 establishments in California, All articl...
# Faunts             [2000 establishments in Alberta, All articles ...
# Faust              [All articles needing additional references, A...  _(band)
# Favourite_Sons     [All articles with dead external links, Articl...
# Feadz              [Articles with hCards, Articles with short des...
#
# [333 rows x 2 columns]

# %%
## just backing up
backup_cat=df_cat.copy()
backup_data = df_data.copy()

# %% [markdown]
# ## Concatenating the two dataframes to find out which method is better

# %%
df = pd.concat([df_cat, df_data], axis=1, sort=False)
df
# Out:
#                                                                          categories  \
# Dj_Spooky                         [1970 births, All BLP articles lacking sources...
# Django_Django                     [Articles with hCards, Because Music artists, ...
# Dna                               [Articles with Curlie links, Articles with hAu...
# Dntel                             [All BLP articles lacking sources, American el...
# Do_Make_Say_Think                 [1995 establishments in Ontario, All articles ...
# ...                                                                             ...
# Father_Yod_And_The_Source_Family                                                NaN
# Father'S_Children                                                               NaN
# Faust,_Dlek                                                                     NaN
# Fc/Kahuna                                                                       NaN
# Fe-Mail                                                                         NaN
#
#                                  suffix gender_data
# Dj_Spooky                                      male
# Django_Django                               unknown
# Dna                                         unknown
# Dntel                                          male
# Do_Make_Say_Think                           unknown
# ...                                 ...         ...
# Father_Yod_And_The_Source_Family    NaN     unknown
# Father'S_Children                   NaN     unknown
# Faust,_Dlek                         NaN     unknown
# Fc/Kahuna                           NaN     unknown
# Fe-Mail                             NaN     unknown
#
# [500 rows x 3 columns]

# %%
## replace the nan values to make the next step work

df.categories = df.categories.fillna("not found")
df.suffix = df.suffix.fillna("")

# %%
def find_gender_cat(df, band_dict):
    df["gender_cat"] = "unknown"
    for band in band_dict:
        for cat in df.loc[band,"categories"]:
            if (("male" in cat) or ("Female" in cat) or ("Boy" in cat) or ("boy" in cat)):
                df.loc[band,"gender_cat"] = "male"
            if (("Female" in cat) or ("female" in cat) or ("girl" in cat) or ("Girl" in cat)):
                df.loc[band,"gender_cat"] = "female"
            if ("Transgender" in cat or "transsexual"in cat):
                df.loc[band,"gender_cat"] = "other"
                
find_gender_cat(df, list(df.index))
df
# Out:
#                                                                          categories  \
# Dj_Spooky                         [1970 births, All BLP articles lacking sources...
# Django_Django                     [Articles with hCards, Because Music artists, ...
# Dna                               [Articles with Curlie links, Articles with hAu...
# Dntel                             [All BLP articles lacking sources, American el...
# Do_Make_Say_Think                 [1995 establishments in Ontario, All articles ...
# ...                                                                             ...
# Father_Yod_And_The_Source_Family                                          not found
# Father'S_Children                                                         not found
# Faust,_Dlek                                                               not found
# Fc/Kahuna                                                                 not found
# Fe-Mail                                                                   not found
#
#                                  suffix gender_data gender_cat
# Dj_Spooky                                      male    unknown
# Django_Django                               unknown    unknown
# Dna                                         unknown    unknown
# Dntel                                          male    unknown
# Do_Make_Say_Think                           unknown    unknown
# ...                                 ...         ...        ...
# Father_Yod_And_The_Source_Family            unknown    unknown
# Father'S_Children                           unknown    unknown
# Faust,_Dlek                                 unknown    unknown
# Fc/Kahuna                                   unknown    unknown
# Fe-Mail                                     unknown    unknown
#
# [500 rows x 4 columns]

# %%
#where do cat and data gender not lign up?

df[df["gender_cat"] != df["gender_data"]]
# Out:
#                                                                 categories  \
# Dj_Spooky                [1970 births, All BLP articles lacking sources...
# Dntel                    [All BLP articles lacking sources, American el...
# Doctor_Rockit            [1972 births, All BLP articles lacking sources...
# Dosh                     [1972 births, American electronic musicians, A...
# Doveman                  [1981 births, 21st-century American keyboardis...
# Dr._Octagon              [Fictional extraterrestrial characters, Fictio...
# Drop_The_Lime            [American electronic musicians, American peopl...
# Du_Blonde                [1990 births, 21st-century British singers, Ar...
# Dudley_Perkins           [All article disambiguation pages, All disambi...
# Dum_Dum_Girls            [All-female bands, All articles with unsourced...
# East_India_Youth         [1991 births, Articles with hCards, CS1 Italia...
# East_River_Pipe          [All BLP articles lacking sources, Articles wi...
# Ebo_Taylor               [1936 births, Articles with hCards, Articles w...
# Edwyn_Collins            [1959 births, All BLP articles lacking sources...
# Eef_Barzelay             [1970 births, 21st-century American singers, 4...
# Efrim_Manuel_Menuck      [1970 births, 21st-century Canadian guitarists...
# Egyptian_Lover           [1963 births, 21st-century American rappers, A...
# Egyptrixx                [Articles with short description, Canadian ele...
# Eine_Kleine_Nacht_Musik  [1978 births, 20th-century English musicians, ...
# Ekkehard_Ehlers          [1974 births, All stub articles, Articles with...
# El_Guincho               [1983 births, All BLP articles lacking sources...
# El_Perro_Del_Mar         [All articles needing additional references, A...
# El-B                     [All BLP articles lacking sources, All stub ar...
# Electrelane              [All-female bands, Articles with hCards, Artic...
# Electric_Company         [1966 births, All articles lacking reliable re...
# Electrik_Red             [American girl groups, Articles with hCards, D...
# Electronicat             [Articles with hCards, Articles with short des...
# Elephant_Micah           [Articles with hCards, Earlham College alumni,...
# Eliot_Lipp               [All NPOV disputes, All Wikipedia articles in ...
# Elizabeth_Morris         [1946 births, 21st-century British physicists,...
# Eluvium                  [All articles with dead external links, Ambien...
# Elysia_Crampton          [1986 births, American electronic musicians, A...
# Emika                    [1986 births, 21st-century English singers, 21...
# Emmanuel_Jal             [1980s births, All articles with dead external...
# Emmy_The_Great           [1984 births, 21st-century English singers, 21...
# Emperor_X                [1979 births, 21st-century American singers, A...
# Ensemble                 [1975 births, All BLP articles lacking sources...
# Erase_Errata             [1999 establishments in California, All-female...
# Eric_Copeland            [21st-century American musicians, All stub art...
# Eric_Malmberg            [All BLP articles lacking sources, All stub ar...
# Eric_Matthews            [1969 births, All BLP articles lacking sources...
# Erik_Friedlander         [1960 births, Articles with hCards, Avant-gard...
# Erkin_Koray              [1941 births, All articles needing additional ...
# Eskimeaux                [American female guitarists, American female r...
# Eskmo                    [All articles lacking reliable references, All...
# Especia                  [2012 establishments in Japan, All stub articl...
# Evian_Christ             [1989 births, Articles with hCards, British DJ...
# Ewan_Pearson             [1972 births, All BLP articles lacking sources...
# Ex_Hex                   [All-female bands, All stub articles, American...
# Ex-Girl                  [All-female bands, All articles covered by Wik...
# Ezra_Furman              [1986 births, 21st-century American guitarists...
# Fannypack                [All stub articles, American dance music group...
# Fatboy_Slim              [1963 births, All articles with dead external ...
# Fatima_Al_Qadiri         [1981 births, Articles containing Arabic-langu...
# Faultline                [All articles lacking in-text citations, All a...
# Feadz                    [Articles with hCards, Articles with short des...
#
#                               suffix         gender_data gender_cat
# Dj_Spooky                                           male    unknown
# Dntel                                               male    unknown
# Doctor_Rockit                                       male    unknown
# Dosh                     _(musician)                male    unknown
# Doveman                                             male    unknown
# Dr._Octagon                                         male    unknown
# Drop_The_Lime                                       male    unknown
# Du_Blonde                                     non-binary      other
# Dudley_Perkins                                      male    unknown
# Dum_Dum_Girls                                    unknown     female
# East_India_Youth                                    male    unknown
# East_River_Pipe                                     male    unknown
# Ebo_Taylor                                          male    unknown
# Edwyn_Collins                                       male    unknown
# Eef_Barzelay                                        male    unknown
# Efrim_Manuel_Menuck                                 male    unknown
# Egyptian_Lover                                      male    unknown
# Egyptrixx                                           male    unknown
# Eine_Kleine_Nacht_Musik                             male    unknown
# Ekkehard_Ehlers                                     male    unknown
# El_Guincho                                          male    unknown
# El_Perro_Del_Mar                                  female    unknown
# El-B                                                male    unknown
# Electrelane                                      unknown     female
# Electric_Company             _(band)                male    unknown
# Electrik_Red                                     unknown     female
# Electronicat                                        male    unknown
# Elephant_Micah                                      male    unknown
# Eliot_Lipp                                          male    unknown
# Elizabeth_Morris                                 unknown     female
# Eluvium                  _(musician)                male    unknown
# Elysia_Crampton                                   female      other
# Emika                                             female    unknown
# Emmanuel_Jal                                        male    unknown
# Emmy_The_Great                                    female    unknown
# Emperor_X                                           male    unknown
# Ensemble                     _(band)                male    unknown
# Erase_Errata                                     unknown     female
# Eric_Copeland                                       male    unknown
# Eric_Malmberg                                       male    unknown
# Eric_Matthews            _(musician)                male    unknown
# Erik_Friedlander                                    male    unknown
# Erkin_Koray                                         male    unknown
# Eskimeaux                                        unknown     female
# Eskmo                                               male    unknown
# Especia                                          unknown     female
# Evian_Christ                                        male    unknown
# Ewan_Pearson                                        male    unknown
# Ex_Hex                       _(band)             unknown     female
# Ex-Girl                                          unknown     female
# Ezra_Furman                           transgender female      other
# Fannypack                                        unknown       male
# Fatboy_Slim                                         male    unknown
# Fatima_Al_Qadiri                                  female    unknown
# Faultline                _(musician)                male    unknown
# Feadz                                               male    unknown

# %%
#df.to_csv('some list.csv') ### To save

#df = pd.read_csv('some list.csv') ### to load
#df.rename(columns={"Unnamed: 0": "artist"}, inplace=True)
#df.set_index("artist")
#df["categories"] = df.categories.apply(lambda x: x.replace("[", "").replace("]", "").replace("'", "").split(", "))

# %% [markdown]
# ## We got some wrong results.
# for example articles linking to disambiguation pages.

# %% [markdown]
# ## Returns all bands / artists with disambiguation pages
# This means we have been linked to the wrong page. However, since (almost) none of them had a gender assigned to them it doesn't seem to be a huge problem right now. We might look into the root of the problem at some later time

# %%
selection = ["All disambiguation pages"]
mask = df.categories.apply(lambda x: np.intersect1d(x, selection).size > 0)
disamb = df[mask]
disamb
# Out:
#                                                         categories   suffix  \
# Do_Or_Die        [All article disambiguation pages, All disambi...
# Doom             [All article disambiguation pages, All disambi...  _(band)
# Doss             [All article disambiguation pages, All disambi...
# Dual_Identity    [All article disambiguation pages, All disambi...
# Dudley_Perkins   [All article disambiguation pages, All disambi...
# Dusted           [All article disambiguation pages, All disambi...  _(band)
# Earth            [All article disambiguation pages, All disambi...  _(band)
# Eaters           [All article disambiguation pages, All disambi...
# Ema              [All article disambiguation pages, All disambi...
# Embrace          [All article disambiguation pages, All disambi...  _(band)
# Emc              [All article disambiguation pages, All disambi...
# En               [All article disambiguation pages, All disambi...
# Eola             [All article disambiguation pages, All disambi...
# Es               [All article disambiguation pages, All disambi...
# Eula             [All article disambiguation pages, All disambi...
# Evangelista      [All article disambiguation pages, All disambi...
# Exile            [All article disambiguation pages, All disambi...  _(band)
# Eyeless_In_Gaza  [All article disambiguation pages, All disambi...
# False            [All article disambiguation pages, All disambi...
# Family_Band      [All article disambiguation pages, All disambi...
# Family_Portrait  [All article disambiguation pages, All disambi...
# Farben           [All article disambiguation pages, All disambi...
# Fatima           [All article disambiguation pages, All disambi...
#
#                 gender_data gender_cat
# Do_Or_Die           unknown    unknown
# Doom                unknown    unknown
# Doss                unknown    unknown
# Dual_Identity       unknown    unknown
# Dudley_Perkins         male    unknown
# Dusted              unknown    unknown
# Earth               unknown    unknown
# Eaters              unknown    unknown
# Ema                 unknown    unknown
# Embrace             unknown    unknown
# Emc                 unknown    unknown
# En                  unknown    unknown
# Eola                unknown    unknown
# Es                  unknown    unknown
# Eula                unknown    unknown
# Evangelista         unknown    unknown
# Exile               unknown    unknown
# Eyeless_In_Gaza     unknown    unknown
# False               unknown    unknown
# Family_Band         unknown    unknown
# Family_Portrait     unknown    unknown
# Farben              unknown    unknown
# Fatima              unknown    unknown

# %% [markdown]
# ## 3. Approach: Using the pronouns

# %%
#band_list = band_list.str.title().str.strip().str.replace(" ", "_").str.replace("&", "%26")
def pronoun_gender(df, band_list, verbose=True, limit=2):
    
    time_before = time.time()
    new_df = df.copy()
    new_df["gender_pronoun"] = "unknown"
    male_identifiers = r'\bhe\b|\bhis\b'
    male_expr = re.compile(male_identifiers, re.IGNORECASE)

    female_identifiers = r'\bshe\b|\bher\b'
    female_expr = re.compile(female_identifiers, re.IGNORECASE)

    base_url = "https://en.wikipedia.org/wiki/"
    
    for counter, band in enumerate(band_list.str.title().str.strip().str.replace(" ", "_").str.replace("&", "%26")):              
        if df.loc[band]["suffix"] != "_(band)": 
            
            pronoun = "unknown"
            
            if verbose:
                print (f"working on band number {counter} of {len(band_list)}", end="\r")  
                
            url = base_url + f"{band}" + df.loc[band]["suffix"]

            response = requests.get(url)
            soup = BeautifulSoup(response.text, "html.parser")
            spoon = soup.find(id="mw-content-text").find_all("p", limit=limit)

            male = male_expr.findall(str(spoon))
            female = female_expr.findall(str(spoon))

            if len(male) > len (female):
                pronoun = "male" 
            elif len(male) < len (female):
                pronoun = "female"
            new_df.loc[band]["gender_pronoun"] = pronoun
    elapsed_time = time.time() - time_before
    print(f"this approach took {elapsed_time} seconds for a total of {len(band_list)} bands")
            
    return new_df

# %%
df = pronoun_gender(df, bands[2000:2500], limit=2, verbose=True)
#df_after.gender.value_counts()
# Out:
# this approach took 166.46960616111755 seconds for a total of 500 bands

# %%
## Where gender_data  and gender_pronoun are not the same. Quite a big list...(over10%)
df[(df["gender_data"] == "unknown" ) & ( df["gender_pronoun"] != "unknown" )]
# Out:
#                                                                              categories  \
# Dolorean                              [1999 establishments in Oregon, Articles with ...
# Dope_Body                             [American noise rock music groups, Articles wi...
# Doughboyz_Cashout                     [American record labels, Companies based in At...
# Drive_Like_Jehu                       [American emo musical groups, American post-ha...
# Drowners                              [Alternative rock groups from New York (state)...
# Dum_Dum_Girls                         [All-female bands, All articles with unsourced...
# Dungen                                [1999 establishments in Sweden, All articles n...
# Eagles_Of_Death_Metal                 [1998 establishments in California, All articl...
# Eartheater                            [1989 births, 21st-century American women musi...
# Edward_Sharpe_%26_The_Magnetic_Zeros  [2005 establishments in California, All articl...
# Effi_Briest                           [1896 German novels, Adultery in novels, All a...
# El_Michels_Affair                     [American funk musical groups, American soul m...
# Electric_President                    [Articles with hCards, Electronic music groups...
# Electrik_Red                          [American girl groups, Articles with hCards, D...
# Eleventh_Dream_Day                    [All articles needing additional references, A...
# Elf_Power                             [All articles needing additional references, A...
# Elizabeth_Morris                      [1946 births, 21st-century British physicists,...
# Epmd                                  [All articles that may contain original resear...
# Eric_B._%26_Rakim                     [1986 establishments in New York (state), Afri...
# Eskimeaux                             [American female guitarists, American female r...
# Ex_Models                             [All articles covered by WikiProject Wikify, A...
# Ex_Reverie                            [Musical groups from Philadelphia, Psychedelic...
# Explosions_In_The_Sky                 [1999 establishments in Texas, American post-r...
# Extra_Golden                          [American world music groups, Kenyan musical g...
# Eyeball_Skeleton                      [All articles with dead external links, Articl...
# Eyedea_%26_Abilities                  [1993 establishments in Minnesota, American hi...
# Fan_Modine                            [All stub articles, Indie pop groups from Mass...
# Faun_Fables                           [1999 establishments in California, All articl...
#
#                                            suffix gender_data gender_cat  \
# Dolorean                                              unknown    unknown
# Dope_Body                                             unknown    unknown
# Doughboyz_Cashout                                     unknown    unknown
# Drive_Like_Jehu                                       unknown    unknown
# Drowners                                              unknown    unknown
# Dum_Dum_Girls                                         unknown     female
# Dungen                                                unknown    unknown
# Eagles_Of_Death_Metal                                 unknown    unknown
# Eartheater                            _(musician)     unknown    unknown
# Edward_Sharpe_%26_The_Magnetic_Zeros                  unknown    unknown
# Effi_Briest                                           unknown    unknown
# El_Michels_Affair                                     unknown    unknown
# Electric_President                                    unknown    unknown
# Electrik_Red                                          unknown     female
# Eleventh_Dream_Day                                    unknown    unknown
# Elf_Power                                             unknown    unknown
# Elizabeth_Morris                                      unknown     female
# Epmd                                                  unknown    unknown
# Eric_B._%26_Rakim                                     unknown    unknown
# Eskimeaux                                             unknown     female
# Ex_Models                                             unknown    unknown
# Ex_Reverie                                            unknown    unknown
# Explosions_In_The_Sky                                 unknown    unknown
# Extra_Golden                                          unknown    unknown
# Eyeball_Skeleton                                      unknown    unknown
# Eyedea_%26_Abilities                                  unknown    unknown
# Fan_Modine                                            unknown    unknown
# Faun_Fables                                           unknown    unknown
#
#                                      gender_pronoun
# Dolorean                                       male
# Dope_Body                                      male
# Doughboyz_Cashout                              male
# Drive_Like_Jehu                                male
# Drowners                                       male
# Dum_Dum_Girls                                female
# Dungen                                         male
# Eagles_Of_Death_Metal                          male
# Eartheater                                   female
# Edward_Sharpe_%26_The_Magnetic_Zeros           male
# Effi_Briest                                    male
# El_Michels_Affair                              male
# Electric_President                             male
# Electrik_Red                                   male
# Eleventh_Dream_Day                           female
# Elf_Power                                      male
# Elizabeth_Morris                             female
# Epmd                                           male
# Eric_B._%26_Rakim                              male
# Eskimeaux                                    female
# Ex_Models                                      male
# Ex_Reverie                                     male
# Explosions_In_The_Sky                          male
# Extra_Golden                                   male
# Eyeball_Skeleton                               male
# Eyedea_%26_Abilities                           male
# Fan_Modine                                     male
# Faun_Fables                                    male

# %%
df.to_csv('500 samples.csv') ### Saving the dataset
